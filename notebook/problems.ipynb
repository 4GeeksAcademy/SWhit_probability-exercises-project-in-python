# %% [markdown]
# # Probability exercises

# %% [markdown]
# ## Exercise 1
#
# Two dices are thrown once and the total score is observed. Use a simulation to find the estimated probability that the total score is even or greater than 7.  A simulation is a repetition of the same experiment multiple times to observe its behavior:
#
# - Run the experiment 1000 times (roll 2 dice 1000 times, and sum the number of both dices).
# - Keep track of the number of times that the sum was either greater than 7 or an even number.
# - Divide the number from step 2 by the number of iterations (1000).

# %%
# TODO
import random

def rolling_dice_exeriment(rolls):
    keep_track = 0
    for i in range(rolls):
        dice1 = random.randint(1, 6)
        dice2 = random.randint(1, 6)
        total = dice1 + dice2
        
        if (total % 2 ==0) or (total > 7):
            keep_track += 1

    result = keep_track / rolls
    return result

est_prob = rolling_dice_exeriment(1000)

print(f'''The estimated probability that the total score is even or greater than 7 is {est_prob * 100:.2f}%''')
# Out:
# The estimated probability that the total score is even or greater than 7 is 65.50%

# %% [markdown]
# ## Exercise 2
#
# A box contains 10 white balls, 20 red balls and 30 green balls. If we take 5 balls from the box with replacement (we take the ball, observe what color it is and put it back into the box). We want to know the probability of:
#
# 1. Take 3 white and 2 red.
# 2. Take all of the same color.
#
# Run the experiment 1000 times and calculate the above probabilities.

# %%
ball_box = {}

# Create the box of balls
for i in range(60):
    if i < 10:
        ball_box[i] = "White"
    elif (i > 9) and (i < 30):
        ball_box[i] = "Red"
    else:
        ball_box[i] = "Green"


            
# TODO

# %% [markdown]
# ## Turn this to a list for easier use

# %%
ball_box_list = list(ball_box.values())
print(ball_box_list)
# Out:
# ['White', 'White', 'White', 'White', 'White', 'White', 'White', 'White', 'White', 'White', 'Red', 'Red', 'Red', 'Red', 'Red', 'Red', 'Red', 'Red', 'Red', 'Red', 'Red', 'Red', 'Red', 'Red', 'Red', 'Red', 'Red', 'Red', 'Red', 'Red', 'Green', 'Green', 'Green', 'Green', 'Green', 'Green', 'Green', 'Green', 'Green', 'Green', 'Green', 'Green', 'Green', 'Green', 'Green', 'Green', 'Green', 'Green', 'Green', 'Green', 'Green', 'Green', 'Green', 'Green', 'Green', 'Green', 'Green', 'Green', 'Green', 'Green']

# %%
import random

# Store counts here
count_3white_2red = 0 
count_all_same = 0

# Run loop 1000 times
for i in range(1000):

    draws = [] # Draw 5 balls with replacement, and hold the 5 colors we draw
    for i in range(5):  # Run loop 5 times for our draw
        draws.append(random.choice(ball_box_list)) # .append we add the color to the draw list

    # Count how many times we get each color
    w = draws.count('White')
    r = draws.count('Red')
    g = draws.count('Green')

    # Did we get the 3 / 2?
    if w == 3 and r == 2:
        count_3white_2red += 1
        
    # How many times did we get all the same color?
    if w == 5 or r == 5 or g == 5:
        count_all_same += 1

prob1 = count_3white_2red / 1000
prob2 = count_all_same / 1000

print(f"Probability of 3 White and 2 Red: {prob1 * 100:.2f}%")
print(f"Probability of all same color: {prob2 * 100:.2f}%")
# Out:
# Probability of 3 White and 2 Red: 0.60%
# Probability of all same color: 4.20%
